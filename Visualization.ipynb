# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#      epoch      loss       acc
# 0        1  3.564774  0.144447
# 1        2  3.066239  0.202704
# 2        3  2.773530  0.247794
# 3        4  2.675797  0.275736
# 4        5  2.599337  0.296732
# ..     ...       ...       ...
# 495    496  0.459131  0.853103
# 496    497  0.460924  0.850889
# 497    498  0.455339  0.852413
# 498    499  0.456218  0.852000
# 499    500  0.458212  0.852068
#
# [500 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
